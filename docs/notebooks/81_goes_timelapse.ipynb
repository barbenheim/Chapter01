# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gee-community/geemap/blob/master/docs/notebooks/81_goes_timelapse.ipynb)

# %% [markdown]
# Uncomment the following line to install [geemap](https://geemap.org) if needed.
#
# This notebook is adapted from Justin Braaten's [JavaScript example](https://code.earthengine.google.com/57245f2d3d04233765c42fb5ef19c1f4). Credits to Justin Braaten. See also his Medium post - [GOES in Earth Engine](https://jstnbraaten.medium.com/goes-in-earth-engine-53fbc8783c16).

# %%
import os
import ee
import geemap

# %%
# !pip install -U geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_771/3320031026.py in <cell line: 0>()
# ----> 1 geemap.update_package()
#
# AttributeError: module 'geemap' has no attribute 'update_package'

# %%
m = geemap.ee_initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# /tmp/ipykernel_771/312053607.py in <cell line: 0>()
# ----> 1 m = geemap.ee_initialize()
#
# /usr/local/lib/python3.12/dist-packages/geemap/coreutils.py in ee_initialize(token_name, auth_mode, auth_args, user_agent_prefix, project, **kwargs)
#     108         if in_colab_shell() and (ee.data._get_state().credentials is None):
#     109             ee.Authenticate()
# --> 110             ee.Initialize(**kwargs)
#     111             return
#     112         else:
#
# /usr/local/lib/python3.12/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      37           if new_key not in kwargs:
#      38             kwargs[new_key] = old_key_val
# ---> 39       return func(*args, **kwargs)
#      40
#      41     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/ee/__init__.py in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     241   empty_project_ok = isinstance(credentials, service_account.Credentials)
#     242   if not is_valid_project and not empty_project_ok:
# --> 243     raise EEException(NO_PROJECT_EXCEPTION)
#     244
#     245   data.initialize(
#
# EEException: ee.Initialize: no project found. Call with project= or see http://goo.gle/ee-auth.

# %%
region = ee.Geometry.Polygon(
    [
        [
            [-159.5954379282731, 60.40883060191719],
            [-159.5954379282731, 24.517881970830725],
            [-114.2438754282731, 24.517881970830725],
            [-114.2438754282731, 60.40883060191719],
        ]
    ],
    None,
    False,
)

# %%
start_date = "2021-10-24T14:00:00"
end_date = "2021-10-25T01:00:00"
data = "GOES-17"
scan = "full_disk"

# %%
col = geemap.goes_timeseries(start_date, end_date, data, scan, region)

# %%
visParams = {
    "bands": ["CMI_C02", "CMI_GREEN", "CMI_C01"],
    "min": 0,
    "max": 0.8,
    "dimensions": 700,
    "framesPerSecond": 9,
    "region": region,
    "crs": col.first().projection(),
}

# %%
out_dir = os.path.expanduser("~/Downloads")
out_gif = os.path.join(out_dir, "goes_timelapse.gif")
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
geemap.download_ee_video(col, visParams, out_gif)

# %%
timestamps = geemap.image_dates(col, date_format="YYYY-MM-dd HH:mm").getInfo()

# %%
geemap.add_text_to_gif(
    out_gif,
    out_gif,
    xy=("3%", "3%"),
    text_sequence=timestamps,
    font_size=20,
    font_color="#ffffff",
)

# %% [markdown]
# All the above steps can be reduced to just one line of code using the `goes_timelapse()` function.

# %%
timelapse = geemap.goes_timelapse(
    region, out_gif, start_date, end_date, data, scan, framesPerSecond=10
)
geemap.show_image(timelapse)
